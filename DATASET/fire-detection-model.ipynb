# %%
# Importing Required Libraries.
from PIL import Image
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import keras
import os

# %%
piclist=[]

# Loading fire images, using PIL.image to resize.
# for file in os.listdir("/kaggle/input/fire-dataset/fire_dataset/fire_images"): # Forest Fire.
for file in os.listdir("/kaggle/input/candles-dataset/Images/001"): # Candles 
    # Resizing and converting to numpy array.
#     img=np.array(Image.open(f"/kaggle/input/fire-dataset/fire_dataset/fire_images/{file}").resize((86,48), Image.Resampling.LANCZOS)) # Forest Fire
    img=np.array(Image.open(f"/kaggle/input/candles-dataset/Images/001/{file}").resize((86,48), Image.Resampling.LANCZOS)) # candles.
    # checking if resize was successful, then appending the np array to list.
    if img.shape==(48,86,3):
        piclist.append(img)
print (len(piclist))

# Loading non-fire images, using PIL.Image and resize.
for file in os.listdir("/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data"): # Forest Non Fire.
    # Resizing and converting to numpy array.
    img=np.array(Image.open(f"/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data/{file}").resize((86,48), Image.Resampling.LANCZOS)) # Forest non fire.
    # checking if resize was successful, then appending the np array to list.
    if img.shape==(48,86,3):
        piclist.append(img)
    if len(piclist) >2000:
        break

for file in os.listdir("/kaggle/input/personal-room-20032023"): # Candles 
    # Resizing and converting to numpy array.
    img=np.array(Image.open(f"/kaggle/input/personal-room-20032023/{file}").resize((86,48), Image.Resampling.LANCZOS)) # candles.
    # checking if resize was successful, then appending the np array to list.
    if img.shape==(48,86,3):
        piclist.append(img)

print (len(piclist))

# stacking the individual arrays in piclist into a 3D numpy array.
TrainStack=np.stack(piclist)
# Out:
# 477
# 2124

# %%
# Creating binary labels for each image.
# 0 = non-fire & 1 = fire.
# labels=[[0]*751+[1]*(990-751)] #751, 990
# labels=[[0]*477+[1]*(716-477)] # 477, 716 
# labels=[[0]*477+[1]*(5726-477)] # 477, 5726
# Reduced
labels=[[0]*477+[1]*(2124-477)] # 477, 


# flatten the multi-dimentional array, returns a one-dimentional array.
labels=np.array(labels).flatten()

# converting the labels into one-hot encoding.
y = to_categorical(labels).astype(int)

# %%
# Spliting data into training & testing sets using `train_test_split` from the sklearn.model_selection module.
# X_train, X_test and y_train, ytest are the output for the training and testing data.  
X_train,X_test,y_train,y_test = train_test_split(TrainStack,y,test_size=0.3)

# %%
def MHA(inputs, head_size=128, num_heads=4, ff_dim=256, dropout=0.3): 
    x = keras.layers.LayerNormalization(epsilon=1e-6)(inputs) 
    x = keras.layers.MultiHeadAttention( key_dim=head_size, num_heads=num_heads, dropout=dropout )(x, x) 
    x = keras.layers.Dropout(dropout)(x) 
    return x + inputs

# %%
def build_model(input_shape):
    """
    Function that defines a Neural Network API, using the keras API.
    
    @input_shape: Tuple of the shape size and rgb example (48,86,3)
    Returns: Keras, Neural Network Model.
    """
    # Define input layer.
    inputs = keras.layers.Input(shape=input_shape)
    x = inputs
    # Defining the first convolutional layer: with 32 filters of size (3,3) to the input data.
    # Using the `relu` (rectified linear unit) activation function, that'll replace the negative values in the input with zero.
    # Kernel initializer specifies the layer weight, `he_uniform` is a variance sccaling initializer.
    x = keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform')(x)
    # Defining the Max Pooling Layer, performs down-sampling of the input data by taking the max value from a (2, 2) window.
    x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
    # Defining the 2nd  Convolutional layer:, applying 64 filters.
    x = keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform')(x)
    x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x) # Defining the 2nd Max Pooling Layer.
    # Batch Normalization layer: normalizes the activations of the previous layer by subtracting the batch mean and 
    # dividing by the batch standard deviation.
    x = keras.layers.BatchNormalization()(x)
    # Defining the 3rd Convolutional layer.
    x = keras.layers.Conv2D(128, kernel_size=(3,3), activation='relu', kernel_initializer='he_uniform')(x)
    x = keras.layers.MaxPooling2D(pool_size=(2,2))(x) # Defining the 3rd Pax Pooling Layer.
    # tensor
    for _ in range(4): 
        x = MHA(x)
    # Flatten layer: This layer flattens the output of the previous layer into a 1D tensor, 
    # which is required for input to the next dense layer.
    x = keras.layers.Flatten()(x)
    # Dense layer with 128 neurons and `relu` activation: applies a dense connection to the input data
    # each neuron in the layer is connected to all the neurons in the previous later.
    x = keras.layers.Dense(128, activation="relu")(x)
    # Randomly sets 40% of neurons to zero during each forward pass to prevent overfitting.
    x = keras.layers.Dropout(0.4)(x)
    # Dense Layer with 1024 neurons and `relu` activation.
    x = keras.layers.Dense(1024, activation="relu")(x) 
    x = keras.layers.Dropout(0.4)(x) # Randomly sets 40% of neurons to zero during each forward pass to prevent overfitting.
    # Dense layer with 2 neurons and `softmax` activation: the output layer with 2 neurons corresponding 
    # to the 2 possible classes. The `softmax` activation function is used to produce a probability-like output for each class.
    x = keras.layers.Dense(2, activation="softmax")(x)
    # returns a Keras Model Instance, it consists of all the layers and the tensors connected between them allowing 
    # to be used for training and inference.
    return keras.Model(inputs, x)

# %%
# Training the Model.

# Defining learning rate scheduling, learning rate is multiplied by a factor of `0.96` after `100000 steps of training.
# This helps to gradually decrease the learning rate, which can make the training process smoother.
initial_learning_rate = 0.00001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True)

# List of Metrics that will be used by the model to evaluate its performance during the training.
# here we'll have measures such as true/false positive/negative, caterogical accuracy, precision, recall,
# area under the ROC Curve and area under the precision-recall curve.
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]



model=build_model((48,86,3)) # Build the model using the function that will define the architecture of the model.

# Callback to save the best model weights to a file named `fire.h5` after each epoch.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
#     "fire.h5", save_best_only=True
    "candle.h5", save_best_only=True
)
# stop training if validation accuracy doesn't improve for `100` epochs.
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_categorical_accuracy", patience=100)
# model.summary()

# Compiling the model using categorical crossentropy loss, an Adam optimizer with the learning rate defined by lr_schedule,
# and the metrics defined in METRICS.
model.compile(loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=METRICS)
# The model is then trained on the training data X_train and y_train, evaluated on the validation data X_test and y_test,
# with a batch size of 10 and 100 epochs. The training process is monitored by the checkpoint_cb and early_stopping_cb callbacks.
# The training history is stored in the History variable.
History=model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=10,epochs=100,callbacks=[checkpoint_cb, early_stopping_cb],verbose=1)
# Out:
# Epoch 1/100
# 2023-03-20 07:10:31.073164: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/model_3/dropout_20/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 149/149 [==============================] - 14s 24ms/step - loss: 0.5669 - tp: 1140.0000 - fp: 346.0000 - tn: 1140.0000 - fn: 346.0000 - categorical_accuracy: 0.7672 - precision: 0.7672 - recall: 0.7672 - auc: 0.8147 - prc: 0.7882 - val_loss: 0.3460 - val_tp: 560.0000 - val_fp: 78.0000 - val_tn: 560.0000 - val_fn: 78.0000 - val_categorical_accuracy: 0.8777 - val_precision: 0.8777 - val_recall: 0.8777 - val_auc: 0.9307 - val_prc: 0.9200
# Epoch 2/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.3714 - tp: 1282.0000 - fp: 204.0000 - tn: 1282.0000 - fn: 204.0000 - categorical_accuracy: 0.8627 - precision: 0.8627 - recall: 0.8627 - auc: 0.9162 - prc: 0.9077 - val_loss: 0.2548 - val_tp: 578.0000 - val_fp: 60.0000 - val_tn: 578.0000 - val_fn: 60.0000 - val_categorical_accuracy: 0.9060 - val_precision: 0.9060 - val_recall: 0.9060 - val_auc: 0.9584 - val_prc: 0.9501
# Epoch 3/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.2849 - tp: 1326.0000 - fp: 160.0000 - tn: 1326.0000 - fn: 160.0000 - categorical_accuracy: 0.8923 - precision: 0.8923 - recall: 0.8923 - auc: 0.9516 - prc: 0.9462 - val_loss: 0.2090 - val_tp: 589.0000 - val_fp: 49.0000 - val_tn: 589.0000 - val_fn: 49.0000 - val_categorical_accuracy: 0.9232 - val_precision: 0.9232 - val_recall: 0.9232 - val_auc: 0.9741 - val_prc: 0.9704
# Epoch 4/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.2292 - tp: 1368.0000 - fp: 118.0000 - tn: 1368.0000 - fn: 118.0000 - categorical_accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - auc: 0.9667 - prc: 0.9634 - val_loss: 0.1638 - val_tp: 596.0000 - val_fp: 42.0000 - val_tn: 596.0000 - val_fn: 42.0000 - val_categorical_accuracy: 0.9342 - val_precision: 0.9342 - val_recall: 0.9342 - val_auc: 0.9839 - val_prc: 0.9829
# Epoch 5/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.1879 - tp: 1384.0000 - fp: 102.0000 - tn: 1384.0000 - fn: 102.0000 - categorical_accuracy: 0.9314 - precision: 0.9314 - recall: 0.9314 - auc: 0.9784 - prc: 0.9785 - val_loss: 0.1569 - val_tp: 599.0000 - val_fp: 39.0000 - val_tn: 599.0000 - val_fn: 39.0000 - val_categorical_accuracy: 0.9389 - val_precision: 0.9389 - val_recall: 0.9389 - val_auc: 0.9863 - val_prc: 0.9853
# Epoch 6/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.1839 - tp: 1385.0000 - fp: 101.0000 - tn: 1385.0000 - fn: 101.0000 - categorical_accuracy: 0.9320 - precision: 0.9320 - recall: 0.9320 - auc: 0.9781 - prc: 0.9782 - val_loss: 0.1299 - val_tp: 610.0000 - val_fp: 28.0000 - val_tn: 610.0000 - val_fn: 28.0000 - val_categorical_accuracy: 0.9561 - val_precision: 0.9561 - val_recall: 0.9561 - val_auc: 0.9895 - val_prc: 0.9886
# Epoch 7/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.1444 - tp: 1416.0000 - fp: 70.0000 - tn: 1416.0000 - fn: 70.0000 - categorical_accuracy: 0.9529 - precision: 0.9529 - recall: 0.9529 - auc: 0.9860 - prc: 0.9856 - val_loss: 0.1283 - val_tp: 608.0000 - val_fp: 30.0000 - val_tn: 608.0000 - val_fn: 30.0000 - val_categorical_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9896 - val_prc: 0.9889
# Epoch 8/100
# 149/149 [==============================] - 4s 25ms/step - loss: 0.1259 - tp: 1419.0000 - fp: 67.0000 - tn: 1419.0000 - fn: 67.0000 - categorical_accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9891 - prc: 0.9883 - val_loss: 0.1097 - val_tp: 611.0000 - val_fp: 27.0000 - val_tn: 611.0000 - val_fn: 27.0000 - val_categorical_accuracy: 0.9577 - val_precision: 0.9577 - val_recall: 0.9577 - val_auc: 0.9928 - val_prc: 0.9930
# Epoch 9/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.1207 - tp: 1416.0000 - fp: 70.0000 - tn: 1416.0000 - fn: 70.0000 - categorical_accuracy: 0.9529 - precision: 0.9529 - recall: 0.9529 - auc: 0.9906 - prc: 0.9904 - val_loss: 0.1071 - val_tp: 614.0000 - val_fp: 24.0000 - val_tn: 614.0000 - val_fn: 24.0000 - val_categorical_accuracy: 0.9624 - val_precision: 0.9624 - val_recall: 0.9624 - val_auc: 0.9933 - val_prc: 0.9935
# Epoch 10/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.1009 - tp: 1435.0000 - fp: 51.0000 - tn: 1435.0000 - fn: 51.0000 - categorical_accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9932 - prc: 0.9929 - val_loss: 0.0967 - val_tp: 615.0000 - val_fp: 23.0000 - val_tn: 615.0000 - val_fn: 23.0000 - val_categorical_accuracy: 0.9639 - val_precision: 0.9639 - val_recall: 0.9639 - val_auc: 0.9945 - val_prc: 0.9947
# Epoch 11/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0914 - tp: 1432.0000 - fp: 54.0000 - tn: 1432.0000 - fn: 54.0000 - categorical_accuracy: 0.9637 - precision: 0.9637 - recall: 0.9637 - auc: 0.9951 - prc: 0.9952 - val_loss: 0.0891 - val_tp: 617.0000 - val_fp: 21.0000 - val_tn: 617.0000 - val_fn: 21.0000 - val_categorical_accuracy: 0.9671 - val_precision: 0.9671 - val_recall: 0.9671 - val_auc: 0.9953 - val_prc: 0.9954
# Epoch 12/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0734 - tp: 1450.0000 - fp: 36.0000 - tn: 1450.0000 - fn: 36.0000 - categorical_accuracy: 0.9758 - precision: 0.9758 - recall: 0.9758 - auc: 0.9961 - prc: 0.9958 - val_loss: 0.0848 - val_tp: 620.0000 - val_fp: 18.0000 - val_tn: 620.0000 - val_fn: 18.0000 - val_categorical_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718 - val_auc: 0.9958 - val_prc: 0.9959
# Epoch 13/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0668 - tp: 1456.0000 - fp: 30.0000 - tn: 1456.0000 - fn: 30.0000 - categorical_accuracy: 0.9798 - precision: 0.9798 - recall: 0.9798 - auc: 0.9965 - prc: 0.9962 - val_loss: 0.0945 - val_tp: 618.0000 - val_fp: 20.0000 - val_tn: 618.0000 - val_fn: 20.0000 - val_categorical_accuracy: 0.9687 - val_precision: 0.9687 - val_recall: 0.9687 - val_auc: 0.9944 - val_prc: 0.9938
# Epoch 14/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0761 - tp: 1436.0000 - fp: 50.0000 - tn: 1436.0000 - fn: 50.0000 - categorical_accuracy: 0.9664 - precision: 0.9664 - recall: 0.9664 - auc: 0.9965 - prc: 0.9966 - val_loss: 0.0773 - val_tp: 620.0000 - val_fp: 18.0000 - val_tn: 620.0000 - val_fn: 18.0000 - val_categorical_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718 - val_auc: 0.9964 - val_prc: 0.9965
# Epoch 15/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0612 - tp: 1450.0000 - fp: 36.0000 - tn: 1450.0000 - fn: 36.0000 - categorical_accuracy: 0.9758 - precision: 0.9758 - recall: 0.9758 - auc: 0.9974 - prc: 0.9971 - val_loss: 0.0693 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9971 - val_prc: 0.9972
# Epoch 16/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0497 - tp: 1454.0000 - fp: 32.0000 - tn: 1454.0000 - fn: 32.0000 - categorical_accuracy: 0.9785 - precision: 0.9785 - recall: 0.9785 - auc: 0.9987 - prc: 0.9987 - val_loss: 0.0694 - val_tp: 619.0000 - val_fp: 19.0000 - val_tn: 619.0000 - val_fn: 19.0000 - val_categorical_accuracy: 0.9702 - val_precision: 0.9702 - val_recall: 0.9702 - val_auc: 0.9971 - val_prc: 0.9972
# Epoch 17/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0446 - tp: 1464.0000 - fp: 22.0000 - tn: 1464.0000 - fn: 22.0000 - categorical_accuracy: 0.9852 - precision: 0.9852 - recall: 0.9852 - auc: 0.9989 - prc: 0.9989 - val_loss: 0.1023 - val_tp: 613.0000 - val_fp: 25.0000 - val_tn: 613.0000 - val_fn: 25.0000 - val_categorical_accuracy: 0.9608 - val_precision: 0.9608 - val_recall: 0.9608 - val_auc: 0.9947 - val_prc: 0.9942
# Epoch 18/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0382 - tp: 1466.0000 - fp: 20.0000 - tn: 1466.0000 - fn: 20.0000 - categorical_accuracy: 0.9865 - precision: 0.9865 - recall: 0.9865 - auc: 0.9991 - prc: 0.9992 - val_loss: 0.0670 - val_tp: 621.0000 - val_fp: 17.0000 - val_tn: 621.0000 - val_fn: 17.0000 - val_categorical_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9975 - val_prc: 0.9976
# Epoch 19/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0406 - tp: 1467.0000 - fp: 19.0000 - tn: 1467.0000 - fn: 19.0000 - categorical_accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9991 - prc: 0.9991 - val_loss: 0.0638 - val_tp: 620.0000 - val_fp: 18.0000 - val_tn: 620.0000 - val_fn: 18.0000 - val_categorical_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718 - val_auc: 0.9977 - val_prc: 0.9977
# Epoch 20/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0325 - tp: 1467.0000 - fp: 19.0000 - tn: 1467.0000 - fn: 19.0000 - categorical_accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9995 - prc: 0.9995 - val_loss: 0.0576 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9980 - val_prc: 0.9981
# Epoch 21/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0279 - tp: 1470.0000 - fp: 16.0000 - tn: 1470.0000 - fn: 16.0000 - categorical_accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9996 - prc: 0.9996 - val_loss: 0.0611 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9967 - val_prc: 0.9962
# Epoch 22/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0247 - tp: 1472.0000 - fp: 14.0000 - tn: 1472.0000 - fn: 14.0000 - categorical_accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - auc: 0.9998 - prc: 0.9998 - val_loss: 0.0589 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9969 - val_prc: 0.9963
# Epoch 23/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0215 - tp: 1479.0000 - fp: 7.0000 - tn: 1479.0000 - fn: 7.0000 - categorical_accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 0.9997 - prc: 0.9997 - val_loss: 0.0814 - val_tp: 618.0000 - val_fp: 20.0000 - val_tn: 618.0000 - val_fn: 20.0000 - val_categorical_accuracy: 0.9687 - val_precision: 0.9687 - val_recall: 0.9687 - val_auc: 0.9955 - val_prc: 0.9950
# Epoch 24/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0196 - tp: 1479.0000 - fp: 7.0000 - tn: 1479.0000 - fn: 7.0000 - categorical_accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 0.9998 - prc: 0.9998 - val_loss: 0.0531 - val_tp: 623.0000 - val_fp: 15.0000 - val_tn: 623.0000 - val_fn: 15.0000 - val_categorical_accuracy: 0.9765 - val_precision: 0.9765 - val_recall: 0.9765 - val_auc: 0.9986 - val_prc: 0.9986
# Epoch 25/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0225 - tp: 1477.0000 - fp: 9.0000 - tn: 1477.0000 - fn: 9.0000 - categorical_accuracy: 0.9939 - precision: 0.9939 - recall: 0.9939 - auc: 0.9997 - prc: 0.9997 - val_loss: 0.0509 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9973 - val_prc: 0.9968
# Epoch 26/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0198 - tp: 1476.0000 - fp: 10.0000 - tn: 1476.0000 - fn: 10.0000 - categorical_accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9997 - prc: 0.9998 - val_loss: 0.0549 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9985 - val_prc: 0.9985
# Epoch 27/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0169 - tp: 1476.0000 - fp: 10.0000 - tn: 1476.0000 - fn: 10.0000 - categorical_accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0832 - val_tp: 621.0000 - val_fp: 17.0000 - val_tn: 621.0000 - val_fn: 17.0000 - val_categorical_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9937 - val_prc: 0.9922
# Epoch 28/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0154 - tp: 1478.0000 - fp: 8.0000 - tn: 1478.0000 - fn: 8.0000 - categorical_accuracy: 0.9946 - precision: 0.9946 - recall: 0.9946 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0599 - val_tp: 623.0000 - val_fp: 15.0000 - val_tn: 623.0000 - val_fn: 15.0000 - val_categorical_accuracy: 0.9765 - val_precision: 0.9765 - val_recall: 0.9765 - val_auc: 0.9971 - val_prc: 0.9966
# Epoch 29/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0239 - tp: 1474.0000 - fp: 12.0000 - tn: 1474.0000 - fn: 12.0000 - categorical_accuracy: 0.9919 - precision: 0.9919 - recall: 0.9919 - auc: 0.9996 - prc: 0.9996 - val_loss: 0.0519 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9960 - val_prc: 0.9949
# Epoch 30/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0116 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0527 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9959 - val_prc: 0.9949
# Epoch 31/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0147 - tp: 1480.0000 - fp: 6.0000 - tn: 1480.0000 - fn: 6.0000 - categorical_accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0549 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9973 - val_prc: 0.9968
# Epoch 32/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0119 - tp: 1477.0000 - fp: 9.0000 - tn: 1477.0000 - fn: 9.0000 - categorical_accuracy: 0.9939 - precision: 0.9939 - recall: 0.9939 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0482 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9974 - val_prc: 0.9969
# Epoch 33/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0229 - tp: 1476.0000 - fp: 10.0000 - tn: 1476.0000 - fn: 10.0000 - categorical_accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9990 - prc: 0.9988 - val_loss: 0.0619 - val_tp: 620.0000 - val_fp: 18.0000 - val_tn: 620.0000 - val_fn: 18.0000 - val_categorical_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718 - val_auc: 0.9968 - val_prc: 0.9963
# Epoch 34/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0163 - tp: 1476.0000 - fp: 10.0000 - tn: 1476.0000 - fn: 10.0000 - categorical_accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9999 - prc: 0.9999 - val_loss: 0.0532 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9986 - val_prc: 0.9986
# Epoch 35/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0097 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0498 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9960 - val_prc: 0.9950
# Epoch 36/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0070 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0540 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9974 - val_prc: 0.9969
# Epoch 37/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0055 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0590 - val_tp: 623.0000 - val_fp: 15.0000 - val_tn: 623.0000 - val_fn: 15.0000 - val_categorical_accuracy: 0.9765 - val_precision: 0.9765 - val_recall: 0.9765 - val_auc: 0.9986 - val_prc: 0.9986
# Epoch 38/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0058 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0518 - val_tp: 623.0000 - val_fp: 15.0000 - val_tn: 623.0000 - val_fn: 15.0000 - val_categorical_accuracy: 0.9765 - val_precision: 0.9765 - val_recall: 0.9765 - val_auc: 0.9975 - val_prc: 0.9970
# Epoch 39/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0091 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0539 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9961 - val_prc: 0.9950
# Epoch 40/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0085 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0903 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9941 - val_prc: 0.9926
# Epoch 41/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0066 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0503 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9989 - val_prc: 0.9989
# Epoch 42/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0040 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0529 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9989 - val_prc: 0.9990
# Epoch 43/100
# 149/149 [==============================] - 3s 17ms/step - loss: 0.0025 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0515 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9990 - val_prc: 0.9990
# Epoch 44/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0030 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0736 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9958 - val_prc: 0.9948
# Epoch 45/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0043 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0669 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9944 - val_prc: 0.9929
# Epoch 46/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0032 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0590 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9975 - val_prc: 0.9970
# Epoch 47/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0026 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0504 - val_tp: 629.0000 - val_fp: 9.0000 - val_tn: 629.0000 - val_fn: 9.0000 - val_categorical_accuracy: 0.9859 - val_precision: 0.9859 - val_recall: 0.9859 - val_auc: 0.9962 - val_prc: 0.9952
# Epoch 48/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0083 - tp: 1480.0000 - fp: 6.0000 - tn: 1480.0000 - fn: 6.0000 - categorical_accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0799 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9942 - val_prc: 0.9927
# Epoch 49/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0037 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0532 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9960 - val_prc: 0.9950
# Epoch 50/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0030 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0826 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9970 - val_prc: 0.9966
# Epoch 51/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0063 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0513 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9990 - val_prc: 0.9991
# Epoch 52/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0028 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0577 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9975 - val_prc: 0.9970
# Epoch 53/100
# 149/149 [==============================] - 2s 16ms/step - loss: 7.3578e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0642 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9960 - val_prc: 0.9950
# Epoch 54/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0049 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0912 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9913 - val_prc: 0.9889
# Epoch 55/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0050 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0608 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9976 - val_prc: 0.9972
# Epoch 56/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0015 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0626 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9961 - val_prc: 0.9951
# Epoch 57/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0025 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0591 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9991 - val_prc: 0.9991
# Epoch 58/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0032 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0775 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9929 - val_prc: 0.9909
# Epoch 59/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0012 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0752 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9960 - val_prc: 0.9950
# Epoch 60/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0021 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0633 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9962 - val_prc: 0.9952
# Epoch 61/100
# 149/149 [==============================] - 3s 19ms/step - loss: 4.7737e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0627 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9962 - val_prc: 0.9952
# Epoch 62/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0044 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0819 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9956 - val_prc: 0.9946
# Epoch 63/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0106 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 0.9993 - prc: 0.9991 - val_loss: 0.0508 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9977 - val_prc: 0.9972
# Epoch 64/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0016 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0572 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9977 - val_prc: 0.9972
# Epoch 65/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0026 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0514 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 66/100
# 149/149 [==============================] - 3s 22ms/step - loss: 0.0013 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0586 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 67/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0059 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 0.9993 - prc: 0.9991 - val_loss: 0.0651 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9976 - val_prc: 0.9971
# Epoch 68/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0026 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0822 - val_tp: 622.0000 - val_fp: 16.0000 - val_tn: 622.0000 - val_fn: 16.0000 - val_categorical_accuracy: 0.9749 - val_precision: 0.9749 - val_recall: 0.9749 - val_auc: 0.9958 - val_prc: 0.9948
# Epoch 69/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0015 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0634 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9976 - val_prc: 0.9971
# Epoch 70/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0015 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0627 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9976 - val_prc: 0.9971
# Epoch 71/100
# 149/149 [==============================] - 3s 18ms/step - loss: 5.9560e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0628 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9962 - val_prc: 0.9953
# Epoch 72/100
# 149/149 [==============================] - 3s 20ms/step - loss: 5.0903e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0598 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 73/100
# 149/149 [==============================] - 2s 16ms/step - loss: 4.9917e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0562 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9979 - val_prc: 0.9974
# Epoch 74/100
# 149/149 [==============================] - 2s 16ms/step - loss: 3.3107e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0598 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9963 - val_prc: 0.9953
# Epoch 75/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0017 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0710 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9948 - val_prc: 0.9933
# Epoch 76/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0224 - tp: 1479.0000 - fp: 7.0000 - tn: 1479.0000 - fn: 7.0000 - categorical_accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 0.9986 - prc: 0.9982 - val_loss: 0.0828 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9915 - val_prc: 0.9891
# Epoch 77/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0026 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0615 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9977 - val_prc: 0.9972
# Epoch 78/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0018 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0903 - val_tp: 624.0000 - val_fp: 14.0000 - val_tn: 624.0000 - val_fn: 14.0000 - val_categorical_accuracy: 0.9781 - val_precision: 0.9781 - val_recall: 0.9781 - val_auc: 0.9913 - val_prc: 0.9889
# Epoch 79/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0032 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0700 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9976 - val_prc: 0.9971
# Epoch 80/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0025 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0726 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9961 - val_prc: 0.9951
# Epoch 81/100
# 149/149 [==============================] - 3s 18ms/step - loss: 4.0282e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0643 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9963 - val_prc: 0.9953
# Epoch 82/100
# 149/149 [==============================] - 3s 19ms/step - loss: 5.1618e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0683 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9948 - val_prc: 0.9933
# Epoch 83/100
# 149/149 [==============================] - 2s 16ms/step - loss: 5.2206e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0880 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9931 - val_prc: 0.9912
# Epoch 84/100
# 149/149 [==============================] - 3s 18ms/step - loss: 4.8530e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0837 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9916 - val_prc: 0.9892
# Epoch 85/100
# 149/149 [==============================] - 3s 20ms/step - loss: 7.4935e-04 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0885 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9901 - val_prc: 0.9871
# Epoch 86/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0034 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0634 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 87/100
# 149/149 [==============================] - 3s 18ms/step - loss: 2.9347e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0686 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 88/100
# 149/149 [==============================] - 2s 16ms/step - loss: 1.9887e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0701 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 89/100
# 149/149 [==============================] - 3s 21ms/step - loss: 0.0018 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0560 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9964 - val_prc: 0.9955
# Epoch 90/100
# 149/149 [==============================] - 3s 19ms/step - loss: 0.0013 - tp: 1485.0000 - fp: 1.0000 - tn: 1485.0000 - fn: 1.0000 - categorical_accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0839 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9931 - val_prc: 0.9911
# Epoch 91/100
# 149/149 [==============================] - 2s 17ms/step - loss: 0.0095 - tp: 1482.0000 - fp: 4.0000 - tn: 1482.0000 - fn: 4.0000 - categorical_accuracy: 0.9973 - precision: 0.9973 - recall: 0.9973 - auc: 0.9993 - prc: 0.9991 - val_loss: 0.0539 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9964 - val_prc: 0.9954
# Epoch 92/100
# 149/149 [==============================] - 2s 16ms/step - loss: 8.4784e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0595 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9964 - val_prc: 0.9954
# Epoch 93/100
# 149/149 [==============================] - 3s 20ms/step - loss: 0.0051 - tp: 1483.0000 - fp: 3.0000 - tn: 1483.0000 - fn: 3.0000 - categorical_accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0637 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9962 - val_prc: 0.9952
# Epoch 94/100
# 149/149 [==============================] - 2s 16ms/step - loss: 0.0019 - tp: 1484.0000 - fp: 2.0000 - tn: 1484.0000 - fn: 2.0000 - categorical_accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0945 - val_tp: 623.0000 - val_fp: 15.0000 - val_tn: 623.0000 - val_fn: 15.0000 - val_categorical_accuracy: 0.9765 - val_precision: 0.9765 - val_recall: 0.9765 - val_auc: 0.9912 - val_prc: 0.9887
# Epoch 95/100
# 149/149 [==============================] - 2s 16ms/step - loss: 6.5066e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0732 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9977 - val_prc: 0.9972
# Epoch 96/100
# 149/149 [==============================] - 2s 16ms/step - loss: 2.6780e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0642 - val_tp: 626.0000 - val_fp: 12.0000 - val_tn: 626.0000 - val_fn: 12.0000 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 97/100
# 149/149 [==============================] - 3s 18ms/step - loss: 6.2345e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0553 - val_tp: 628.0000 - val_fp: 10.0000 - val_tn: 628.0000 - val_fn: 10.0000 - val_categorical_accuracy: 0.9843 - val_precision: 0.9843 - val_recall: 0.9843 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 98/100
# 149/149 [==============================] - 3s 19ms/step - loss: 2.7761e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0606 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9978 - val_prc: 0.9973
# Epoch 99/100
# 149/149 [==============================] - 2s 17ms/step - loss: 7.7240e-04 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0850 - val_tp: 625.0000 - val_fp: 13.0000 - val_tn: 625.0000 - val_fn: 13.0000 - val_categorical_accuracy: 0.9796 - val_precision: 0.9796 - val_recall: 0.9796 - val_auc: 0.9945 - val_prc: 0.9930
# Epoch 100/100
# 149/149 [==============================] - 3s 18ms/step - loss: 0.0014 - tp: 1486.0000 - fp: 0.0000e+00 - tn: 1486.0000 - fn: 0.0000e+00 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - prc: 1.0000 - val_loss: 0.0550 - val_tp: 627.0000 - val_fp: 11.0000 - val_tn: 627.0000 - val_fn: 11.0000 - val_categorical_accuracy: 0.9828 - val_precision: 0.9828 - val_recall: 0.9828 - val_auc: 0.9963 - val_prc: 0.9953

# %%
# plot a graph of the validation categorical accuracy over the epochs. 
# `History.history['val_categorical_accuracy'] is a list of the validation categorical accuracy at the end of each epoch.
plt.plot(History.history['val_categorical_accuracy'])

# %%
firelist=['FIRE',"NOT A FIRE"]

CustomDict={}

# Populating the CustomDict dictionary with 25 random entries.
for _ in range(25):
    # Generating a random int between 0 and 989.
#     r=np.random.randint(0,990)
    r=np.random.randint(0,2124)
    # r- th entry in the TrainStack arrya is paired with the true Label, Fire or Not-Fire, and the prediction made by the model
    # when fed when fed the same image stored in the TrainStack[r].
    # The true label is obtained by finding the maximum index of the y[r] array, which is a one-hot encoded representation of the label.
    # The np.argmax function returns the index of the maximum value in the input array, which in this case corresponds to the class label.
    # The predicted label is obtained by passing np.expand_dims(TrainStack[r], axis=0) through the model using the model.predict method.
    # This results in a one-hot encoded prediction that is transformed into the class label in the same way as the true label.
    # Finally, the image, true label, and predicted label are stored in the CustomDict dictionary as a tuple. 
    CustomDict[r]=TrainStack[r],firelist[np.argmax(y[r])],firelist[np.argmax(model.predict(np.expand_dims(TrainStack[r],axis=0)))]
# Out:
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# Creating a 5x5 subplot figure and plots 25 randomly selected images from the TrainStack data set. 
# The actual and predicted class of each image is displayed as a label below the image.
fig, axs = plt.subplots(5,5,figsize=(25,25)) # creates a 5x5 subplot figure with a figure size of 25x25. axs is an array of subplots.
# loops over the first 25 elements of CustomDict, getting the key of the element in CustomDict and the marker == index of the element.
for key,marker in zip(CustomDict,range(25)):
    # plots the image stored in the first element of CustomDict[key] on the current subplot specified by axs[marker//5,marker%5]
    axs[marker//5,marker%5].imshow(CustomDict[key][0])
    # sets the x label of the current subplot to a string that includes both the actual and predicted class of the image. 
    # The actual class is stored in the second element of the value of CustomDict[key] and the predicted class is stored in the third element. 
    # The fontsize is set to 20.
    axs[marker//5,marker%5].set_xlabel("Pred: "+str(CustomDict[key][2]+' Actu: '+str(CustomDict[key][1])),fontsize = 20.0)
    

fig.tight_layout() # automatically adjusts the subplots so that they fit nicely within the figure.

plt.savefig(f"Fire.jpg") # saves the figure to a JPEG image file named "Fire.jpg
